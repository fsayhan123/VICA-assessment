# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('insurance_data.csv', sep = ';')
df.head()
# Out:
#    insuree# gender  is45OrOlder isMarried hasKids  insuredMonths  \
# 0         1      F          0.0       Yes     Yes             23
# 1         2      F          1.0        No      No             42
# 2         3      F          0.0       Yes      No             72
# 3         4      F          0.0       Yes     Yes             13
# 4         5      F          0.0        No      No             37
#
#   termLifeInsurance multipleTermLifePolicies healthInsurance healthRiders  \
# 0               Yes                       No              No          NaN
# 1               Yes                      Yes         Class A            3
# 2               Yes                       No              No          NaN
# 3               Yes                       No              No          NaN
# 4               Yes                      Yes         Class A          3,4
#
#    premiumFrequency eStatements monthlyPremium totalPremium renewal
# 0              12.0         Yes          19,65       451,55       Y
# 1               1.0         Yes          84,65      3541,35       N
# 2              12.0          No           19,4      1496,45       Y
# 3              12.0          No          19,55        265,3       Y
# 4               1.0          No          100,3       3541,4       Y

# %%
df.describe(include = 'all')
# Out:
#            insuree# gender  is45OrOlder isMarried hasKids  insuredMonths  \
# count   5500.000000   5387  5404.000000      5500    5500    5500.000000
# unique          NaN      2          NaN         2       2            NaN
# top             NaN      M          NaN        No      No            NaN
# freq            NaN   2719          NaN      2843    3857            NaN
# mean    2750.500000    NaN     0.162657       NaN     NaN      34.678909
# std     1587.857571    NaN     0.369087       NaN     NaN      42.225326
# min        1.000000    NaN     0.000000       NaN     NaN       0.000000
# 25%     1375.750000    NaN     0.000000       NaN     NaN       9.000000
# 50%     2750.500000    NaN     0.000000       NaN     NaN      29.000000
# 75%     4125.250000    NaN     0.000000       NaN     NaN      56.000000
# max     5500.000000    NaN     1.000000       NaN     NaN     720.000000
#
#        termLifeInsurance multipleTermLifePolicies healthInsurance  \
# count               5500                     5500            5500
# unique                 2                        4               3
# top                  Yes                       No         Class A
# freq                4969                     2654            2419
# mean                 NaN                      NaN             NaN
# std                  NaN                      NaN             NaN
# min                  NaN                      NaN             NaN
# 25%                  NaN                      NaN             NaN
# 50%                  NaN                      NaN             NaN
# 75%                  NaN                      NaN             NaN
# max                  NaN                      NaN             NaN
#
#        healthRiders  premiumFrequency eStatements monthlyPremium totalPremium  \
# count          3518       5386.000000        5500           5500         5500
# unique           15               NaN           2           1524         5174
# top             3,4               NaN         Yes          20,05         20,2
# freq            474               NaN        3225             49           10
# mean            NaN          4.086892         NaN            NaN          NaN
# std             NaN          4.548742         NaN            NaN          NaN
# min             NaN          1.000000         NaN            NaN          NaN
# 25%             NaN          1.000000         NaN            NaN          NaN
# 50%             NaN          1.000000         NaN            NaN          NaN
# 75%             NaN          3.000000         NaN            NaN          NaN
# max             NaN         12.000000         NaN            NaN          NaN
#
#        renewal
# count     5500
# unique       2
# top          Y
# freq      4023
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df['gender'].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
df[df['insuredMonths'] == 0]
# Out:
#       insuree# gender  is45OrOlder isMarried hasKids  insuredMonths  \
# 22          23      M          0.0       Yes     Yes              0
# 99         100      M          0.0       Yes     Yes              0
# 1428      1429      F          0.0       Yes     Yes              0
# 2411      2412      M          0.0       Yes     Yes              0
# 2643      2644      F          0.0       Yes     Yes              0
# 3332      3333      M          0.0        No     Yes              0
# 4585      4586      M          0.0        No     Yes              0
# 4611      4612      M          0.0       Yes     Yes              0
# 4915      4916      F          0.0       Yes     Yes              0
#
#      termLifeInsurance   multipleTermLifePolicies healthInsurance  \
# 22                 Yes                         No              No
# 99                 Yes                        Yes              No
# 1428               Yes                         No         Class B
# 2411               Yes                        Yes              No
# 2643               Yes                        Yes         Class B
# 3332               Yes                         No              No
# 4585               Yes                        Yes         Class B
# 4611               Yes                         No              No
# 4915                No  no term life policy taken         Class B
#
#      healthRiders  premiumFrequency eStatements monthlyPremium totalPremium  \
# 22            NaN               3.0         Yes           19,7
# 99            NaN              12.0          No          25,35
# 1428      1,2,3,4              12.0          No          80,85
# 2411          NaN              12.0          No          25,75
# 2643          2,3              12.0          No          73,35
# 3332          NaN              12.0          No          20,25
# 4585          1,2              12.0         Yes           61,9
# 4611          NaN              12.0          No          19,85
# 4915          1,3              12.0         Yes          52,55
#
#      renewal
# 22         Y
# 99         Y
# 1428       Y
# 2411       Y
# 2643       Y
# 3332       Y
# 4585       Y
# 4611       Y
# 4915       Y

# %%
#What are our potential missing values?
#is45OrOlder 
#premium_frequency
#totalPremium 
df = pd.read_csv('insurance_data.csv', sep = ';')
transform(df)
# Out:
# [{'insuree#': 1,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 23,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 19.65,
#   'totalPremium': 451.55,
#   'renewal': False},
#  {'insuree#': 2,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 42,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 84.65,
#   'totalPremium': 3541.35,
#   'renewal': False},
#  {'insuree#': 3,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 72,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 19.4,
#   'totalPremium': 1496.45,
#   'renewal': False},
#  {'insuree#': 4,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 13,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 19.55,
#   'totalPremium': 265.3,
#   'renewal': False},
#  {'insuree#': 5,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 37,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 100.3,
#   'totalPremium': 3541.4,
#   'renewal': False},
#  {'insuree#': 6,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 3,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 81.35,
#   'totalPremium': 233.7,
#   'renewal': False},
#  {'insuree#': 7,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': True,
#   'insuredMonths': 24,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 21.05,
#   'totalPremium': 531.55,
#   'renewal': False},
#  {'insuree#': 8,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 24,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 85.95,
#   'totalPremium': 2107.15,
#   'renewal': False},
#  {'insuree#': 9,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 24,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 56.35,
#   'totalPremium': 1381.2,
#   'renewal': False},
#  {'insuree#': 10,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 31,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 99.95,
#   'totalPremium': 3186.65,
#   'renewal': False},
#  {'insuree#': 11,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 49.5,
#   'totalPremium': 49.5,
#   'renewal': False},
#  {'insuree#': 12,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 57,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 53.35,
#   'totalPremium': 3090.05,
#   'renewal': False},
#  {'insuree#': 13,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 6,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 98.25,
#   'totalPremium': 560.6,
#   'renewal': False},
#  {'insuree#': 14,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 19.55,
#   'totalPremium': 19.55,
#   'renewal': False},
#  {'insuree#': 15,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 7,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 20.25,
#   'totalPremium': 129.15,
#   'renewal': False},
#  {'insuree#': 16,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 65,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3, 4]},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 91.55,
#   'totalPremium': 5963.95,
#   'renewal': False},
#  {'insuree#': 17,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 40,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 101.3,
#   'totalPremium': 4113.1,
#   'renewal': False},
#  {'insuree#': 18,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 18,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 74.8,
#   'totalPremium': 1438.05,
#   'renewal': False},
#  {'insuree#': 19,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 15,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 100.15,
#   'totalPremium': 1415.0,
#   'renewal': False},
#  {'insuree#': 20,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 2,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 44.6,
#   'totalPremium': 97.1,
#   'renewal': False},
#  {'insuree#': 21,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 4,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': None,
#   'eStatements': True,
#   'monthlyPremium': 74.45,
#   'totalPremium': 294.45,
#   'renewal': False},
#  {'insuree#': 22,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 69,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 95.35,
#   'totalPremium': 6382.0,
#   'renewal': False},
#  {'insuree#': 23,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 0,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 19.7,
#   'totalPremium': None,
#   'renewal': False},
#  {'insuree#': 24,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 85.45,
#   'totalPremium': 85.45,
#   'renewal': False},
#  {'insuree#': 25,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 70.6,
#   'totalPremium': 70.6,
#   'renewal': False},
#  {'insuree#': 26,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 40,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 89.6,
#   'totalPremium': 3488.15,
#   'renewal': False},
#  {'insuree#': 27,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 59,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 99.45,
#   'totalPremium': 5623.7,
#   'renewal': False},
#  {'insuree#': 28,
#   'gender': nan,
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 19.75,
#   'totalPremium': 19.75,
#   'renewal': False},
#  {'insuree#': 29,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 16,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 94.65,
#   'totalPremium': 1461.15,
#   'renewal': False},
#  {'insuree#': 30,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 23,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 68.75,
#   'totalPremium': 1689.45,
#   'renewal': False},
#  {'insuree#': 31,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 66,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 20.0,
#   'totalPremium': 1374.2,
#   'renewal': False},
#  {'insuree#': 32,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 27,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 53.8,
#   'totalPremium': 1389.85,
#   'renewal': False},
#  {'insuree#': 33,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 2,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 53.85,
#   'totalPremium': 108.15,
#   'renewal': False},
#  {'insuree#': 34,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': True,
#   'insuredMonths': 15,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 19.65,
#   'totalPremium': 270.6,
#   'renewal': False},
#  {'insuree#': 35,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 29,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 48.95,
#   'totalPremium': 1323.7,
#   'renewal': False},
#  {'insuree#': 36,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': True,
#   'insuredMonths': 11,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 19.7,
#   'totalPremium': 216.2,
#   'renewal': False},
#  {'insuree#': 37,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 61,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 25.0,
#   'totalPremium': 1501.75,
#   'renewal': False},
#  {'insuree#': 38,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 6,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 19.15,
#   'totalPremium': 124.4,
#   'renewal': False},
#  {'insuree#': 39,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 39,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 59.85,
#   'totalPremium': 2341.5,
#   'renewal': False},
#  {'insuree#': 40,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 41,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 94.3,
#   'totalPremium': 3893.6,
#   'renewal': False},
#  {'insuree#': 41,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': True,
#   'insuredMonths': 3,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 70.7,
#   'totalPremium': 225.65,
#   'renewal': False},
#  {'insuree#': 42,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 72,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 3, 4]},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 105.25,
#   'totalPremium': 7609.75,
#   'renewal': False},
#  {'insuree#': 43,
#   'gender': nan,
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 62,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 90.7,
#   'totalPremium': 5586.45,
#   'renewal': False},
#  {'insuree#': 44,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 2,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 80.2,
#   'totalPremium': 146.05,
#   'renewal': False},
#  {'insuree#': 45,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 3,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 69.85,
#   'totalPremium': 199.85,
#   'renewal': False},
#  {'insuree#': 46,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 6,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 49.15,
#   'totalPremium': 295.65,
#   'renewal': False},
#  {'insuree#': 47,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 29.7,
#   'totalPremium': 29.7,
#   'renewal': False},
#  {'insuree#': 48,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': True,
#   'insuredMonths': 4,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 84.05,
#   'totalPremium': 333.55,
#   'renewal': False},
#  {'insuree#': 49,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 70,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3]},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 80.7,
#   'totalPremium': 5617.95,
#   'renewal': False},
#  {'insuree#': 50,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 4,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 74.9,
#   'totalPremium': 321.75,
#   'renewal': False},
#  {'insuree#': 51,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 56,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 86.4,
#   'totalPremium': 4922.4,
#   'renewal': False},
#  {'insuree#': 52,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 30,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 64.5,
#   'totalPremium': 1888.45,
#   'renewal': False},
#  {'insuree#': 53,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 22,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 54.2,
#   'totalPremium': 1152.7,
#   'renewal': False},
#  {'insuree#': 54,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 41,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 51.35,
#   'totalPremium': 2075.1,
#   'renewal': False},
#  {'insuree#': 55,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 40,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 102.65,
#   'totalPremium': 4108.15,
#   'renewal': False},
#  {'insuree#': 56,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 71,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 92.0,
#   'totalPremium': 6585.2,
#   'renewal': False},
#  {'insuree#': 57,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': True,
#   'insuredMonths': 72,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 19.9,
#   'totalPremium': 1529.65,
#   'renewal': False},
#  {'insuree#': 58,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 69,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 20.2,
#   'totalPremium': 1376.5,
#   'renewal': False},
#  {'insuree#': 59,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 54,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3, 4]},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 108.0,
#   'totalPremium': 5760.65,
#   'renewal': False},
#  {'insuree#': 60,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 72,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3, 4]},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 90.6,
#   'totalPremium': 6441.85,
#   'renewal': False},
#  {'insuree#': 61,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 71,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 4]},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 89.45,
#   'totalPremium': 6435.25,
#   'renewal': False},
#  {'insuree#': 62,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 20,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 98.55,
#   'totalPremium': 1842.8,
#   'renewal': False},
#  {'insuree#': 63,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 26,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 50.35,
#   'totalPremium': 1277.5,
#   'renewal': False},
#  {'insuree#': 64,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 55,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 19.4,
#   'totalPremium': 1083.0,
#   'renewal': False},
#  {'insuree#': 65,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 4,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 44.55,
#   'totalPremium': 174.3,
#   'renewal': False},
#  {'insuree#': 66,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 51,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 3]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 95.15,
#   'totalPremium': 5000.05,
#   'renewal': False},
#  {'insuree#': 67,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 5,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 51.0,
#   'totalPremium': 305.95,
#   'renewal': False},
#  {'insuree#': 68,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 58,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 3]},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 75.8,
#   'totalPremium': 4415.75,
#   'renewal': False},
#  {'insuree#': 69,
#   'gender': 'M',
#   'is45OrOlder': None,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 32,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 104.9,
#   'totalPremium': 3351.55,
#   'renewal': False},
#  {'insuree#': 70,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 40,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 65.1,
#   'totalPremium': 2586.0,
#   'renewal': False},
#  {'insuree#': 71,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 54,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 104.1,
#   'totalPremium': 5645.8,
#   'renewal': False},
#  {'insuree#': 72,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 170,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 102.55,
#   'totalPremium': 1742.5,
#   'renewal': False},
#  {'insuree#': 73,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 55,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 104.15,
#   'totalPremium': 5743.05,
#   'renewal': False},
#  {'insuree#': 74,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 12,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 20.5,
#   'totalPremium': 255.5,
#   'renewal': False},
#  {'insuree#': 75,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 72,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 109.15,
#   'totalPremium': 7789.6,
#   'renewal': False},
#  {'insuree#': 76,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 41,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 104.45,
#   'totalPremium': 4162.05,
#   'renewal': False},
#  {'insuree#': 77,
#   'gender': nan,
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 67,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [4]},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 69.9,
#   'totalPremium': 4615.9,
#   'renewal': False},
#  {'insuree#': 78,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 14,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 80.05,
#   'totalPremium': 1112.3,
#   'renewal': False},
#  {'insuree#': 79,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 43,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 55.45,
#   'totalPremium': 2444.25,
#   'renewal': False},
#  {'insuree#': 80,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 5,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 64.0,
#   'totalPremium': 370.25,
#   'renewal': False},
#  {'insuree#': 81,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 33,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 93.55,
#   'totalPremium': 3055.5,
#   'renewal': False},
#  {'insuree#': 82,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 12,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 19.35,
#   'totalPremium': 219.35,
#   'renewal': False},
#  {'insuree#': 83,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 3,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 35.1,
#   'totalPremium': 101.1,
#   'renewal': False},
#  {'insuree#': 84,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 20.2,
#   'totalPremium': 20.2,
#   'renewal': False},
#  {'insuree#': 85,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 60,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 19.25,
#   'totalPremium': 1103.25,
#   'renewal': False},
#  {'insuree#': 86,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 25,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 89.05,
#   'totalPremium': 2177.45,
#   'renewal': False},
#  {'insuree#': 87,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 3,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 19.6,
#   'totalPremium': 61.35,
#   'renewal': False},
#  {'insuree#': 88,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 39,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 3, 4]},
#   'premiumFrequency': None,
#   'eStatements': True,
#   'monthlyPremium': 100.45,
#   'totalPremium': 3801.7,
#   'renewal': False},
#  {'insuree#': 89,
#   'gender': nan,
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 72,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2]},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 59.75,
#   'totalPremium': 4265.0,
#   'renewal': False},
#  {'insuree#': 90,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 43,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 104.3,
#   'totalPremium': 4451.85,
#   'renewal': False},
#  {'insuree#': 91,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 9,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2]},
#   'premiumFrequency': None,
#   'eStatements': False,
#   'monthlyPremium': 65.0,
#   'totalPremium': 663.05,
#   'renewal': False},
#  {'insuree#': 92,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 45,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 95.95,
#   'totalPremium': 4456.65,
#   'renewal': False},
#  {'insuree#': 93,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 42,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 49.55,
#   'totalPremium': 2077.95,
#   'renewal': False},
#  {'insuree#': 94,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 21,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 68.65,
#   'totalPremium': 1493.2,
#   'renewal': False},
#  {'insuree#': 95,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 70,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 4]},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 49.85,
#   'totalPremium': 3370.2,
#   'renewal': False},
#  {'insuree#': 96,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 3,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 107.95,
#   'totalPremium': 318.6,
#   'renewal': False},
#  {'insuree#': 97,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 70,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 19.85,
#   'totalPremium': 1433.8,
#   'renewal': False},
#  {'insuree#': 98,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 43,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 92.55,
#   'totalPremium': 4039.0,
#   'renewal': False},
#  {'insuree#': 99,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 24,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 96.0,
#   'totalPremium': 2122.45,
#   'renewal': False},
#  {'insuree#': 100,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 0,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 25.35,
#   'totalPremium': None,
#   'renewal': False},
#  {'insuree#': 101,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 39,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 75.25,
#   'totalPremium': 3017.65,
#   'renewal': False},
#  {'insuree#': 102,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 18,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 69.8,
#   'totalPremium': 1221.65,
#   'renewal': False},
#  {'insuree#': 103,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 72,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 3, 4]},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 86.65,
#   'totalPremium': 6094.25,
#   'renewal': False},
#  {'insuree#': 104,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 13,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 96.65,
#   'totalPremium': 1162.85,
#   'renewal': False},
#  {'insuree#': 105,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': True,
#   'insuredMonths': 19,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 20.0,
#   'totalPremium': 377.55,
#   'renewal': False},
#  {'insuree#': 106,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 7,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 90.45,
#   'totalPremium': 593.45,
#   'renewal': False},
#  {'insuree#': 107,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 36,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 20.35,
#   'totalPremium': 695.85,
#   'renewal': False},
#  {'insuree#': 108,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 56,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 103.2,
#   'totalPremium': 5873.75,
#   'renewal': False},
#  {'insuree#': 109,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 66,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 3, 4]},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 102.4,
#   'totalPremium': 6471.85,
#   'renewal': False},
#  {'insuree#': 110,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 44,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 5395.0,
#   'totalPremium': 23754.0,
#   'renewal': False},
#  {'insuree#': 111,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 6,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 89.35,
#   'totalPremium': 567.8,
#   'renewal': False},
#  {'insuree#': 112,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 3,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 20.0,
#   'totalPremium': 63.6,
#   'renewal': False},
#  {'insuree#': 113,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 3,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 69.55,
#   'totalPremium': 222.3,
#   'renewal': False},
#  {'insuree#': 114,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 29,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 98.5,
#   'totalPremium': 3004.15,
#   'renewal': False},
#  {'insuree#': 115,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 22,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 20.85,
#   'totalPremium': 450.65,
#   'renewal': False},
#  {'insuree#': 116,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 7,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 81.1,
#   'totalPremium': 576.65,
#   'renewal': False},
#  {'insuree#': 117,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 79.95,
#   'totalPremium': 79.95,
#   'renewal': False},
#  {'insuree#': 118,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 34,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 30.4,
#   'totalPremium': 938.65,
#   'renewal': False},
#  {'insuree#': 119,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 9,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 77.65,
#   'totalPremium': 714.15,
#   'renewal': False},
#  {'insuree#': 120,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 31,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 55.25,
#   'totalPremium': 1715.65,
#   'renewal': False},
#  {'insuree#': 121,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 62,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 25.8,
#   'totalPremium': 1563.95,
#   'renewal': False},
#  {'insuree#': 122,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 2,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 91.15,
#   'totalPremium': 168.5,
#   'renewal': False},
#  {'insuree#': 123,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 69.6,
#   'totalPremium': 69.6,
#   'renewal': False},
#  {'insuree#': 124,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 15,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 19.4,
#   'totalPremium': 289.3,
#   'renewal': False},
#  {'insuree#': 125,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 5,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 70.0,
#   'totalPremium': 347.4,
#   'renewal': False},
#  {'insuree#': 126,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 40,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 26.2,
#   'totalPremium': 1077.5,
#   'renewal': False},
#  {'insuree#': 127,
#   'gender': 'M',
#   'is45OrOlder': None,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 8,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 54.4,
#   'totalPremium': 475.1,
# ...
#   'totalPremium': 2983.65,
#   'renewal': False},
#  {'insuree#': 959,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 38,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 20.45,
#   'totalPremium': 781.25,
#   'renewal': False},
#  {'insuree#': 960,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 47,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 104.1,
#   'totalPremium': 5135.15,
#   'renewal': False},
#  {'insuree#': 961,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 38,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3]},
#   'premiumFrequency': None,
#   'eStatements': False,
#   'monthlyPremium': 70.6,
#   'totalPremium': 2708.2,
#   'renewal': False},
#  {'insuree#': 962,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 37,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 80.05,
#   'totalPremium': 3019.1,
#   'renewal': False},
#  {'insuree#': 963,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 25,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 71.05,
#   'totalPremium': 1837.7,
#   'renewal': False},
#  {'insuree#': 964,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 19.1,
#   'totalPremium': 19.1,
#   'renewal': False},
#  {'insuree#': 965,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 69.9,
#   'totalPremium': 69.9,
#   'renewal': False},
#  {'insuree#': 966,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 51,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 29.45,
#   'totalPremium': 1459.35,
#   'renewal': False},
#  {'insuree#': 967,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 25.05,
#   'totalPremium': 25.05,
#   'renewal': False},
#  {'insuree#': 968,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 23,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 20.85,
#   'totalPremium': 473.9,
#   'renewal': False},
#  {'insuree#': 969,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': True,
#   'insuredMonths': 55,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 19.1,
#   'totalPremium': 1001.5,
#   'renewal': False},
#  {'insuree#': 970,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 52,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 53.75,
#   'totalPremium': 2790.65,
#   'renewal': False},
#  {'insuree#': 971,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 27,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 89.2,
#   'totalPremium': 2383.6,
#   'renewal': False},
#  {'insuree#': 972,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 33,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 79.15,
#   'totalPremium': 2531.4,
#   'renewal': False},
#  {'insuree#': 973,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 7,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 7385.0,
#   'totalPremium': 51125.0,
#   'renewal': False},
#  {'insuree#': 974,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 31,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 75.5,
#   'totalPremium': 2424.45,
#   'renewal': False},
#  {'insuree#': 975,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 19.65,
#   'totalPremium': 19.65,
#   'renewal': False},
#  {'insuree#': 976,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 64,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 4]},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 74.35,
#   'totalPremium': 4759.55,
#   'renewal': False},
#  {'insuree#': 977,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': True,
#   'insuredMonths': 12,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 21.05,
#   'totalPremium': 235.8,
#   'renewal': False},
#  {'insuree#': 978,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 38,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 3]},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 74.05,
#   'totalPremium': 2802.3,
#   'renewal': False},
#  {'insuree#': 979,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 65,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 110.8,
#   'totalPremium': 7245.9,
#   'renewal': False},
#  {'insuree#': 980,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 37,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 3]},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 64.65,
#   'totalPremium': 2347.85,
#   'renewal': False},
#  {'insuree#': 981,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 33,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 110.45,
#   'totalPremium': 3655.45,
#   'renewal': False},
#  {'insuree#': 982,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 35,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 54.95,
#   'totalPremium': 1916.0,
#   'renewal': False},
#  {'insuree#': 983,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 64,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 4]},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 93.4,
#   'totalPremium': 5822.3,
#   'renewal': False},
#  {'insuree#': 984,
#   'gender': 'F',
#   'is45OrOlder': True,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 2,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': None,
#   'eStatements': True,
#   'monthlyPremium': 70.35,
#   'totalPremium': 139.05,
#   'renewal': False},
#  {'insuree#': 985,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 35,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 20.05,
#   'totalPremium': 746.75,
#   'renewal': False},
#  {'insuree#': 986,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 24,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 49.55,
#   'totalPremium': 1210.4,
#   'renewal': False},
#  {'insuree#': 987,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 42,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 4]},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 73.9,
#   'totalPremium': 3160.55,
#   'renewal': False},
#  {'insuree#': 988,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 65,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2, 4]},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 72.45,
#   'totalPremium': 4653.85,
#   'renewal': False},
#  {'insuree#': 989,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 51,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 20.65,
#   'totalPremium': 1020.75,
#   'renewal': False},
#  {'insuree#': 990,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 48,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 60.6,
#   'totalPremium': 2985.25,
#   'renewal': False},
#  {'insuree#': 991,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 55,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [1, 2]},
#   'premiumFrequency': 3,
#   'eStatements': False,
#   'monthlyPremium': 60.0,
#   'totalPremium': 3316.1,
#   'renewal': False},
#  {'insuree#': 992,
#   'gender': 'M',
#   'is45OrOlder': None,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 66,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 99.5,
#   'totalPremium': 6822.15,
#   'renewal': False},
#  {'insuree#': 993,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 53,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2, 3, 4]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 111.8,
#   'totalPremium': 5809.75,
#   'renewal': False},
#  {'insuree#': 994,
#   'gender': 'M',
#   'is45OrOlder': True,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 64,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 12,
#   'eStatements': False,
#   'monthlyPremium': 102.1,
#   'totalPremium': 6538.45,
#   'renewal': False},
#  {'insuree#': 995,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 1,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': []},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 69.15,
#   'totalPremium': 69.15,
#   'renewal': False},
#  {'insuree#': 996,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 70,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 19.2,
#   'totalPremium': 1401.4,
#   'renewal': False},
#  {'insuree#': 997,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': False,
#   'insuredMonths': 13,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3, 4]},
#   'premiumFrequency': 1,
#   'eStatements': True,
#   'monthlyPremium': 102.25,
#   'totalPremium': 1359.0,
#   'renewal': False},
#  {'insuree#': 998,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': True,
#   'hasKids': True,
#   'insuredMonths': 610,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': True},
#   'healthInsurance': {'hasPolicy': False, 'riders': []},
#   'premiumFrequency': 12,
#   'eStatements': True,
#   'monthlyPremium': 24.1,
#   'totalPremium': 1551.6,
#   'renewal': False},
#  {'insuree#': 999,
#   'gender': 'M',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 11,
#   'termLifeInsurance': {'hasPolicy': False, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [3]},
#   'premiumFrequency': 3,
#   'eStatements': True,
#   'monthlyPremium': 416.0,
#   'totalPremium': 4706.0,
#   'renewal': False},
#  {'insuree#': 1000,
#   'gender': 'F',
#   'is45OrOlder': False,
#   'isMarried': False,
#   'hasKids': False,
#   'insuredMonths': 18,
#   'termLifeInsurance': {'hasPolicy': True, 'hasMultiplePolicies': False},
#   'healthInsurance': {'hasPolicy': True, 'riders': [2]},
#   'premiumFrequency': 1,
#   'eStatements': False,
#   'monthlyPremium': 77.8,
#   'totalPremium': 1358.6,
#   'renewal': False},
#  ...]

# %%
df_copy
# Out:
#       insuree# gender is45OrOlder  isMarried  hasKids  insuredMonths  \
# 0            1      F       False       True     True             23
# 1            2      F        True      False    False             42
# 2            3      F       False       True    False             72
# 3            4      F       False       True     True             13
# 4            5      F       False      False    False             37
# ...        ...    ...         ...        ...      ...            ...
# 5495      5496      F       False       True     True              4
# 5496      5497      M       False       True    False              3
# 5497      5498      M       False       True    False             56
# 5498      5499      M       False       True     True             54
# 5499      5500      F       False       True    False             20
#
#       termLifeInsurance  multipleTermLifePolicies  healthInsurance  \
# 0                  True                     False            False
# 1                  True                      True             True
# 2                  True                     False            False
# 3                  True                     False            False
# 4                  True                      True             True
# ...                 ...                       ...              ...
# 5495               True                      True             True
# 5496               True                     False            False
# 5497               True                     False             True
# 5498               True                     False            False
# 5499               True                     False            False
#
#      healthRiders  premiumFrequency  eStatements  monthlyPremium  \
# 0              []              12.0         True           19.65
# 1             [3]               1.0         True           84.65
# 2              []              12.0        False           19.40
# 3              []              12.0        False           19.55
# 4          [3, 4]               1.0        False          100.30
# ...           ...               ...          ...             ...
# 5495          [4]               1.0         True           85.95
# 5496           []               1.0        False           20.00
# 5497          [4]               3.0         True           80.90
# 5498           []              12.0        False           20.40
# 5499           []               3.0        False           20.35
#
#       totalPremium  renewal
# 0           451.55    False
# 1          3541.35    False
# 2          1496.45    False
# 3           265.30    False
# 4          3541.40    False
# ...            ...      ...
# 5495        381.30    False
# 5496         49.65    False
# 5497       4557.50    False
# 5498       1090.60    False
# 5499        393.15    False
#
# [5500 rows x 15 columns]

# %%
access_key = f"mongodb+srv://fsayhan:PEmlxzKLNdItoioC@cluster0.eshsihu.mongodb.net/?retryWrites=true&w=majority"

def clean_data(df):
    def clean_is45orolder(x):
        if not np.isnan(x): #none null
            if x == 1.0:
                return True
            else:
                return False
        else:
            return x
    df_copy = df.copy()
    df_copy['is45OrOlder'] = df_copy['is45OrOlder'].apply(clean_is45orolder)
    df_copy['isMarried'] = df_copy['isMarried'].apply(lambda x: True if x == 'Yes' else False).astype(bool)
    df_copy['hasKids'] = df_copy['hasKids'].apply(lambda x: True if x == 'Yes' else False).astype(bool)
    df_copy['termLifeInsurance'] = df_copy['termLifeInsurance'].apply(lambda x: True if x == 'Yes' else False).astype(bool)
    df_copy['multipleTermLifePolicies'] = df_copy['multipleTermLifePolicies'].apply(lambda x: True if x == 'Yes' else False).astype(bool)
    df_copy['healthInsurance'] = df_copy['healthInsurance'].apply(lambda x: False if x == 'No' else True).astype(bool)
    df_copy['healthRiders'] = df_copy['healthRiders'].apply(lambda x: x.split(',') if type(x) == str else x)
    df_copy['healthRiders'] = df_copy['healthRiders'].apply(lambda x: list(map(lambda y: int(y), x)) if type(x) == list else [])
    df_copy['eStatements'] = df_copy['eStatements'].apply(lambda x: True if x == 'Yes' else False)
    df_copy['totalPremium'] = df_copy['totalPremium'].str.replace(' ', '0')
    df_copy['monthlyPremium'] = df_copy['monthlyPremium'].apply(lambda x: float(x.replace(",", ".")))
    df_copy['totalPremium'] = df_copy['totalPremium'].apply(lambda x: float(x.replace(",", ".")))
    df_copy['renewal'] = df_copy['renewal'].apply(lambda x: True if x == 'Yes' else False)
    return df_copy

def transform(df):
    """
    Does data cleaning and converts a dataframe to a list of dictionaries in the required format 
    Parameters
        ----------
        df: pd.DataFrame 
            df read from insurance_data.csv file
        Returns
        -------
        result : list 
            list of dictionaries, 1 dictionary is 1 record in the df
    """
    df_copy = clean_data(df)
    data_dict = df_copy.to_dict(orient = 'records')
    for data in data_dict:
        if type(data['is45OrOlder']) != str:
            data['is45OrOlder'] = None
        if type(data['is45OrOlder']) != bool:
            data['is45OrOlder'] = None
        if np.isnan(data['premiumFrequency']):
            data['premiumFrequency'] = None
        else:
            data['premiumFrequency'] = int(data['premiumFrequency'])
        if data['totalPremium'] == 0:
            data['totalPremium'] = None
            
        data['termLifeInsurance'] = {
            'hasPolicy': data['termLifeInsurance'],
            'hasMultiplePolicies': data['multipleTermLifePolicies']
        }
        data['healthInsurance'] = {
            'hasPolicy': data['healthInsurance'],
            'riders': data['healthRiders']
        }
        data.pop('healthRiders')
        data.pop('multipleTermLifePolicies')
    return data_dict    
    
def load(access_key, data_dict):
    """
    Converts a dataframe to a list of dictionaries in the required format 
    Parameters
        ----------
        access_key: pd.DataFrame 
            access key required to connect to MongoDB 
        data_dict: list
            data to be uploaded to the MongoDB
        Returns
        -------
        sucess: Boolean
            returns whether the uploading of data was successful 
    """
    pass

def ETL(filepath, access_key):
    """
    Reads the data from the csv, transforms it to the correct NoSQL format and upload to MongoDB
    Parameters
        ----------
        access_key: pd.DataFrame 
            access key required to connect to MongoDB 
        filepath: string
            filepath to load the csv file  
        Returns
        -------
        sucess: boolean
            returns whether the uploading of data was successful 
    """
    pass

# %%
# Out:
# [{'insuree#': 1,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 23,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '19,65',
#   'totalPremium': '451,55',
#   'renewal': 'Y'},
#  {'insuree#': 2,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 42,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '84,65',
#   'totalPremium': '3541,35',
#   'renewal': 'N'},
#  {'insuree#': 3,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 72,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,4',
#   'totalPremium': '1496,45',
#   'renewal': 'Y'},
#  {'insuree#': 4,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 13,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,55',
#   'totalPremium': '265,3',
#   'renewal': 'Y'},
#  {'insuree#': 5,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 37,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '100,3',
#   'totalPremium': '3541,4',
#   'renewal': 'Y'},
#  {'insuree#': 6,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 3,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '81,35',
#   'totalPremium': '233,7',
#   'renewal': 'N'},
#  {'insuree#': 7,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'Yes',
#   'insuredMonths': 24,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '21,05',
#   'totalPremium': '531,55',
#   'renewal': 'Y'},
#  {'insuree#': 8,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 24,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '85,95',
#   'totalPremium': '2107,15',
#   'renewal': 'Y'},
#  {'insuree#': 9,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 24,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '56,35',
#   'totalPremium': '1381,2',
#   'renewal': 'Y'},
#  {'insuree#': 10,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 31,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '99,95',
#   'totalPremium': '3186,65',
#   'renewal': 'N'},
#  {'insuree#': 11,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '49,5',
#   'totalPremium': '49,5',
#   'renewal': 'Y'},
#  {'insuree#': 12,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 57,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '53,35',
#   'totalPremium': '3090,05',
#   'renewal': 'Y'},
#  {'insuree#': 13,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 6,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '98,25',
#   'totalPremium': '560,6',
#   'renewal': 'N'},
#  {'insuree#': 14,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,55',
#   'totalPremium': '19,55',
#   'renewal': 'Y'},
#  {'insuree#': 15,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 7,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20,25',
#   'totalPremium': '129,15',
#   'renewal': 'Y'},
#  {'insuree#': 16,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 65,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,3,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '91,55',
#   'totalPremium': '5963,95',
#   'renewal': 'Y'},
#  {'insuree#': 17,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 40,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '101,3',
#   'totalPremium': '4113,1',
#   'renewal': 'N'},
#  {'insuree#': 18,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 18,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '74,8',
#   'totalPremium': '1438,05',
#   'renewal': 'Y'},
#  {'insuree#': 19,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 15,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '100,15',
#   'totalPremium': '1415',
#   'renewal': 'Y'},
#  {'insuree#': 20,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 2,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '44,6',
#   'totalPremium': '97,1',
#   'renewal': 'N'},
#  {'insuree#': 21,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 4,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': nan,
#   'eStatements': 'Yes',
#   'monthlyPremium': '74,45',
#   'totalPremium': '294,45',
#   'renewal': 'Y'},
#  {'insuree#': 22,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 69,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '95,35',
#   'totalPremium': '6382',
#   'renewal': 'Y'},
#  {'insuree#': 23,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 0,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '19,7',
#   'totalPremium': ' ',
#   'renewal': 'Y'},
#  {'insuree#': 24,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '85,45',
#   'totalPremium': '85,45',
#   'renewal': 'N'},
#  {'insuree#': 25,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '70,6',
#   'totalPremium': '70,6',
#   'renewal': 'N'},
#  {'insuree#': 26,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 40,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '89,6',
#   'totalPremium': '3488,15',
#   'renewal': 'Y'},
#  {'insuree#': 27,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 59,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,2,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '99,45',
#   'totalPremium': '5623,7',
#   'renewal': 'Y'},
#  {'insuree#': 28,
#   'gender': nan,
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '19,75',
#   'totalPremium': '19,75',
#   'renewal': 'Y'},
#  {'insuree#': 29,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 16,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '94,65',
#   'totalPremium': '1461,15',
#   'renewal': 'Y'},
#  {'insuree#': 30,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 23,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '68,75',
#   'totalPremium': '1689,45',
#   'renewal': 'Y'},
#  {'insuree#': 31,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 66,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20',
#   'totalPremium': '1374,2',
#   'renewal': 'Y'},
#  {'insuree#': 32,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 27,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '53,8',
#   'totalPremium': '1389,85',
#   'renewal': 'Y'},
#  {'insuree#': 33,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 2,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '53,85',
#   'totalPremium': '108,15',
#   'renewal': 'N'},
#  {'insuree#': 34,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'Yes',
#   'insuredMonths': 15,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,65',
#   'totalPremium': '270,6',
#   'renewal': 'Y'},
#  {'insuree#': 35,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 29,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '48,95',
#   'totalPremium': '1323,7',
#   'renewal': 'Y'},
#  {'insuree#': 36,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'Yes',
#   'insuredMonths': 11,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,7',
#   'totalPremium': '216,2',
#   'renewal': 'Y'},
#  {'insuree#': 37,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 61,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '25',
#   'totalPremium': '1501,75',
#   'renewal': 'Y'},
#  {'insuree#': 38,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 6,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,15',
#   'totalPremium': '124,4',
#   'renewal': 'Y'},
#  {'insuree#': 39,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 39,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '59,85',
#   'totalPremium': '2341,5',
#   'renewal': 'Y'},
#  {'insuree#': 40,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 41,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,2,3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '94,3',
#   'totalPremium': '3893,6',
#   'renewal': 'Y'},
#  {'insuree#': 41,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'Yes',
#   'insuredMonths': 3,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '70,7',
#   'totalPremium': '225,65',
#   'renewal': 'Y'},
#  {'insuree#': 42,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 72,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,3,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '105,25',
#   'totalPremium': '7609,75',
#   'renewal': 'Y'},
#  {'insuree#': 43,
#   'gender': nan,
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 62,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '90,7',
#   'totalPremium': '5586,45',
#   'renewal': 'Y'},
#  {'insuree#': 44,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 2,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '80,2',
#   'totalPremium': '146,05',
#   'renewal': 'N'},
#  {'insuree#': 45,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 3,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '69,85',
#   'totalPremium': '199,85',
#   'renewal': 'Y'},
#  {'insuree#': 46,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 6,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '49,15',
#   'totalPremium': '295,65',
#   'renewal': 'Y'},
#  {'insuree#': 47,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '29,7',
#   'totalPremium': '29,7',
#   'renewal': 'N'},
#  {'insuree#': 48,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'Yes',
#   'insuredMonths': 4,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '84,05',
#   'totalPremium': '333,55',
#   'renewal': 'N'},
#  {'insuree#': 49,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 70,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,3',
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '80,7',
#   'totalPremium': '5617,95',
#   'renewal': 'Y'},
#  {'insuree#': 50,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 4,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '74,9',
#   'totalPremium': '321,75',
#   'renewal': 'N'},
#  {'insuree#': 51,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 56,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '86,4',
#   'totalPremium': '4922,4',
#   'renewal': 'Y'},
#  {'insuree#': 52,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 30,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '64,5',
#   'totalPremium': '1888,45',
#   'renewal': 'Y'},
#  {'insuree#': 53,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 22,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '54,2',
#   'totalPremium': '1152,7',
#   'renewal': 'N'},
#  {'insuree#': 54,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 41,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '51,35',
#   'totalPremium': '2075,1',
#   'renewal': 'Y'},
#  {'insuree#': 55,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 40,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '102,65',
#   'totalPremium': '4108,15',
#   'renewal': 'Y'},
#  {'insuree#': 56,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 71,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,2',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '92',
#   'totalPremium': '6585,2',
#   'renewal': 'Y'},
#  {'insuree#': 57,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'Yes',
#   'insuredMonths': 72,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,9',
#   'totalPremium': '1529,65',
#   'renewal': 'Y'},
#  {'insuree#': 58,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 69,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20,2',
#   'totalPremium': '1376,5',
#   'renewal': 'Y'},
#  {'insuree#': 59,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 54,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,2,3,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '108',
#   'totalPremium': '5760,65',
#   'renewal': 'Y'},
#  {'insuree#': 60,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 72,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,3,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '90,6',
#   'totalPremium': '6441,85',
#   'renewal': 'Y'},
#  {'insuree#': 61,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 71,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '89,45',
#   'totalPremium': '6435,25',
#   'renewal': 'Y'},
#  {'insuree#': 62,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 20,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '98,55',
#   'totalPremium': '1842,8',
#   'renewal': 'N'},
#  {'insuree#': 63,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 26,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '50,35',
#   'totalPremium': '1277,5',
#   'renewal': 'Y'},
#  {'insuree#': 64,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 55,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,4',
#   'totalPremium': '1083',
#   'renewal': 'Y'},
#  {'insuree#': 65,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 4,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '44,55',
#   'totalPremium': '174,3',
#   'renewal': 'N'},
#  {'insuree#': 66,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 51,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,3',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '95,15',
#   'totalPremium': '5000,05',
#   'renewal': 'Y'},
#  {'insuree#': 67,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 5,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '51',
#   'totalPremium': '305,95',
#   'renewal': 'N'},
#  {'insuree#': 68,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 58,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,3',
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '75,8',
#   'totalPremium': '4415,75',
#   'renewal': 'Y'},
#  {'insuree#': 69,
#   'gender': 'M',
#   'is45OrOlder': nan,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 32,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '104,9',
#   'totalPremium': '3351,55',
#   'renewal': 'N'},
#  {'insuree#': 70,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 40,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '65,1',
#   'totalPremium': '2586',
#   'renewal': 'Y'},
#  {'insuree#': 71,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 54,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '104,1',
#   'totalPremium': '5645,8',
#   'renewal': 'Y'},
#  {'insuree#': 72,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 170,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '102,55',
#   'totalPremium': '1742,5',
#   'renewal': 'Y'},
#  {'insuree#': 73,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 55,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '104,15',
#   'totalPremium': '5743,05',
#   'renewal': 'N'},
#  {'insuree#': 74,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 12,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20,5',
#   'totalPremium': '255,5',
#   'renewal': 'Y'},
#  {'insuree#': 75,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 72,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '109,15',
#   'totalPremium': '7789,6',
#   'renewal': 'Y'},
#  {'insuree#': 76,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 41,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,2,3,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '104,45',
#   'totalPremium': '4162,05',
#   'renewal': 'Y'},
#  {'insuree#': 77,
#   'gender': nan,
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 67,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '69,9',
#   'totalPremium': '4615,9',
#   'renewal': 'Y'},
#  {'insuree#': 78,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 14,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '80,05',
#   'totalPremium': '1112,3',
#   'renewal': 'Y'},
#  {'insuree#': 79,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 43,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '2',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '55,45',
#   'totalPremium': '2444,25',
#   'renewal': 'Y'},
#  {'insuree#': 80,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 5,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '2,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '64',
#   'totalPremium': '370,25',
#   'renewal': 'Y'},
#  {'insuree#': 81,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 33,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,2,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '93,55',
#   'totalPremium': '3055,5',
#   'renewal': 'Y'},
#  {'insuree#': 82,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 12,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '19,35',
#   'totalPremium': '219,35',
#   'renewal': 'Y'},
#  {'insuree#': 83,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 3,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '35,1',
#   'totalPremium': '101,1',
#   'renewal': 'Y'},
#  {'insuree#': 84,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20,2',
#   'totalPremium': '20,2',
#   'renewal': 'Y'},
#  {'insuree#': 85,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 60,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '19,25',
#   'totalPremium': '1103,25',
#   'renewal': 'Y'},
#  {'insuree#': 86,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 25,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '89,05',
#   'totalPremium': '2177,45',
#   'renewal': 'N'},
#  {'insuree#': 87,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 3,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,6',
#   'totalPremium': '61,35',
#   'renewal': 'Y'},
#  {'insuree#': 88,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 39,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,3,4',
#   'premiumFrequency': nan,
#   'eStatements': 'Yes',
#   'monthlyPremium': '100,45',
#   'totalPremium': '3801,7',
#   'renewal': 'Y'},
#  {'insuree#': 89,
#   'gender': nan,
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 72,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2',
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '59,75',
#   'totalPremium': '4265',
#   'renewal': 'Y'},
#  {'insuree#': 90,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 43,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '104,3',
#   'totalPremium': '4451,85',
#   'renewal': 'Y'},
#  {'insuree#': 91,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 9,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2',
#   'premiumFrequency': nan,
#   'eStatements': 'No',
#   'monthlyPremium': '65',
#   'totalPremium': '663,05',
#   'renewal': 'N'},
#  {'insuree#': 92,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 45,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '95,95',
#   'totalPremium': '4456,65',
#   'renewal': 'Y'},
#  {'insuree#': 93,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 42,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '49,55',
#   'totalPremium': '2077,95',
#   'renewal': 'Y'},
#  {'insuree#': 94,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 21,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '68,65',
#   'totalPremium': '1493,2',
#   'renewal': 'Y'},
#  {'insuree#': 95,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 70,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '49,85',
#   'totalPremium': '3370,2',
#   'renewal': 'Y'},
#  {'insuree#': 96,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 3,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '107,95',
#   'totalPremium': '318,6',
#   'renewal': 'Y'},
#  {'insuree#': 97,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 70,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,85',
#   'totalPremium': '1433,8',
#   'renewal': 'Y'},
#  {'insuree#': 98,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 43,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '92,55',
#   'totalPremium': '4039',
#   'renewal': 'Y'},
#  {'insuree#': 99,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 24,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '96',
#   'totalPremium': '2122,45',
#   'renewal': 'N'},
#  {'insuree#': 100,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 0,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '25,35',
#   'totalPremium': ' ',
#   'renewal': 'Y'},
#  {'insuree#': 101,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 39,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '75,25',
#   'totalPremium': '3017,65',
#   'renewal': 'N'},
#  {'insuree#': 102,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 18,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '69,8',
#   'totalPremium': '1221,65',
#   'renewal': 'Y'},
#  {'insuree#': 103,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 72,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,3,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '86,65',
#   'totalPremium': '6094,25',
#   'renewal': 'Y'},
#  {'insuree#': 104,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 13,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '96,65',
#   'totalPremium': '1162,85',
#   'renewal': 'N'},
#  {'insuree#': 105,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'Yes',
#   'insuredMonths': 19,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '20',
#   'totalPremium': '377,55',
#   'renewal': 'Y'},
#  {'insuree#': 106,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 7,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '90,45',
#   'totalPremium': '593,45',
#   'renewal': 'N'},
#  {'insuree#': 107,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 36,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '20,35',
#   'totalPremium': '695,85',
#   'renewal': 'Y'},
#  {'insuree#': 108,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 56,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '103,2',
#   'totalPremium': '5873,75',
#   'renewal': 'Y'},
#  {'insuree#': 109,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 66,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,3,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '102,4',
#   'totalPremium': '6471,85',
#   'renewal': 'Y'},
#  {'insuree#': 110,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 44,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '5395',
#   'totalPremium': '23754',
#   'renewal': 'N'},
#  {'insuree#': 111,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 6,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '89,35',
#   'totalPremium': '567,8',
#   'renewal': 'Y'},
#  {'insuree#': 112,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 3,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20',
#   'totalPremium': '63,6',
#   'renewal': 'Y'},
#  {'insuree#': 113,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 3,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '69,55',
#   'totalPremium': '222,3',
#   'renewal': 'N'},
#  {'insuree#': 114,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 29,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '98,5',
#   'totalPremium': '3004,15',
#   'renewal': 'N'},
#  {'insuree#': 115,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 22,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20,85',
#   'totalPremium': '450,65',
#   'renewal': 'Y'},
#  {'insuree#': 116,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 7,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '81,1',
#   'totalPremium': '576,65',
#   'renewal': 'N'},
#  {'insuree#': 117,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '79,95',
#   'totalPremium': '79,95',
#   'renewal': 'N'},
#  {'insuree#': 118,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 34,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '30,4',
#   'totalPremium': '938,65',
#   'renewal': 'Y'},
#  {'insuree#': 119,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 9,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '77,65',
#   'totalPremium': '714,15',
#   'renewal': 'N'},
#  {'insuree#': 120,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 31,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '55,25',
#   'totalPremium': '1715,65',
#   'renewal': 'N'},
#  {'insuree#': 121,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 62,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '25,8',
#   'totalPremium': '1563,95',
#   'renewal': 'Y'},
#  {'insuree#': 122,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 2,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,2,3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '91,15',
#   'totalPremium': '168,5',
#   'renewal': 'Y'},
#  {'insuree#': 123,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '69,6',
#   'totalPremium': '69,6',
#   'renewal': 'N'},
#  {'insuree#': 124,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 15,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,4',
#   'totalPremium': '289,3',
#   'renewal': 'N'},
#  {'insuree#': 125,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 5,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '70',
#   'totalPremium': '347,4',
#   'renewal': 'N'},
#  {'insuree#': 126,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 40,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '26,2',
#   'totalPremium': '1077,5',
#   'renewal': 'Y'},
#  {'insuree#': 127,
#   'gender': 'M',
#   'is45OrOlder': nan,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 8,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '54,4',
#   'totalPremium': '475,1',
#   'renewal': 'Y'},
#  {'insuree#': 128,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 22,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '83,05',
#   'totalPremium': '1799,3',
#   'renewal': 'Y'},
#  {'insuree#': 129,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 13,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '20,4',
#   'totalPremium': '251,65',
#   'renewal': 'Y'},
#  {'insuree#': 130,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
# ...
#  {'insuree#': 958,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 68,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,3',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '44,8',
#   'totalPremium': '2983,65',
#   'renewal': 'Y'},
#  {'insuree#': 959,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 38,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20,45',
#   'totalPremium': '781,25',
#   'renewal': 'Y'},
#  {'insuree#': 960,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 47,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '104,1',
#   'totalPremium': '5135,15',
#   'renewal': 'Y'},
#  {'insuree#': 961,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 38,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,3',
#   'premiumFrequency': nan,
#   'eStatements': 'No',
#   'monthlyPremium': '70,6',
#   'totalPremium': '2708,2',
#   'renewal': 'Y'},
#  {'insuree#': 962,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 37,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '80,05',
#   'totalPremium': '3019,1',
#   'renewal': 'Y'},
#  {'insuree#': 963,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 25,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '71,05',
#   'totalPremium': '1837,7',
#   'renewal': 'Y'},
#  {'insuree#': 964,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,1',
#   'totalPremium': '19,1',
#   'renewal': 'Y'},
#  {'insuree#': 965,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '69,9',
#   'totalPremium': '69,9',
#   'renewal': 'N'},
#  {'insuree#': 966,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 51,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '29,45',
#   'totalPremium': '1459,35',
#   'renewal': 'Y'},
#  {'insuree#': 967,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'term life policy not taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '25,05',
#   'totalPremium': '25,05',
#   'renewal': 'N'},
#  {'insuree#': 968,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 23,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20,85',
#   'totalPremium': '473,9',
#   'renewal': 'Y'},
#  {'insuree#': 969,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'Yes',
#   'insuredMonths': 55,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,1',
#   'totalPremium': '1001,5',
#   'renewal': 'Y'},
#  {'insuree#': 970,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 52,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '53,75',
#   'totalPremium': '2790,65',
#   'renewal': 'Y'},
#  {'insuree#': 971,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 27,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '89,2',
#   'totalPremium': '2383,6',
#   'renewal': 'Y'},
#  {'insuree#': 972,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 33,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '79,15',
#   'totalPremium': '2531,4',
#   'renewal': 'Y'},
#  {'insuree#': 973,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 7,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '7385',
#   'totalPremium': '51125',
#   'renewal': 'N'},
#  {'insuree#': 974,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 31,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '75,5',
#   'totalPremium': '2424,45',
#   'renewal': 'Y'},
#  {'insuree#': 975,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '19,65',
#   'totalPremium': '19,65',
#   'renewal': 'Y'},
#  {'insuree#': 976,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 64,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '74,35',
#   'totalPremium': '4759,55',
#   'renewal': 'Y'},
#  {'insuree#': 977,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'Yes',
#   'insuredMonths': 12,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '21,05',
#   'totalPremium': '235,8',
#   'renewal': 'Y'},
#  {'insuree#': 978,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 38,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,3',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '74,05',
#   'totalPremium': '2802,3',
#   'renewal': 'Y'},
#  {'insuree#': 979,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 65,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '110,8',
#   'totalPremium': '7245,9',
#   'renewal': 'Y'},
#  {'insuree#': 980,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 37,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,3',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '64,65',
#   'totalPremium': '2347,85',
#   'renewal': 'Y'},
#  {'insuree#': 981,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 33,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '110,45',
#   'totalPremium': '3655,45',
#   'renewal': 'N'},
#  {'insuree#': 982,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 35,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '54,95',
#   'totalPremium': '1916',
#   'renewal': 'Y'},
#  {'insuree#': 983,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 64,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '1,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '93,4',
#   'totalPremium': '5822,3',
#   'renewal': 'Y'},
#  {'insuree#': 984,
#   'gender': 'F',
#   'is45OrOlder': 1.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 2,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': nan,
#   'eStatements': 'Yes',
#   'monthlyPremium': '70,35',
#   'totalPremium': '139,05',
#   'renewal': 'N'},
#  {'insuree#': 985,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 35,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20,05',
#   'totalPremium': '746,75',
#   'renewal': 'Y'},
#  {'insuree#': 986,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 24,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '49,55',
#   'totalPremium': '1210,4',
#   'renewal': 'N'},
#  {'insuree#': 987,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 42,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '73,9',
#   'totalPremium': '3160,55',
#   'renewal': 'N'},
#  {'insuree#': 988,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 65,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '72,45',
#   'totalPremium': '4653,85',
#   'renewal': 'N'},
#  {'insuree#': 989,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 51,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '20,65',
#   'totalPremium': '1020,75',
#   'renewal': 'Y'},
#  {'insuree#': 990,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 48,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '60,6',
#   'totalPremium': '2985,25',
#   'renewal': 'Y'},
#  {'insuree#': 991,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 55,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class B',
#   'healthRiders': '1,2',
#   'premiumFrequency': 3.0,
#   'eStatements': 'No',
#   'monthlyPremium': '60',
#   'totalPremium': '3316,1',
#   'renewal': 'Y'},
#  {'insuree#': 992,
#   'gender': 'M',
#   'is45OrOlder': nan,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 66,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '99,5',
#   'totalPremium': '6822,15',
#   'renewal': 'N'},
#  {'insuree#': 993,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 53,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2,3,4',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '111,8',
#   'totalPremium': '5809,75',
#   'renewal': 'Y'},
#  {'insuree#': 994,
#   'gender': 'M',
#   'is45OrOlder': 1.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 64,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 12.0,
#   'eStatements': 'No',
#   'monthlyPremium': '102,1',
#   'totalPremium': '6538,45',
#   'renewal': 'Y'},
#  {'insuree#': 995,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 1,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': nan,
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '69,15',
#   'totalPremium': '69,15',
#   'renewal': 'N'},
#  {'insuree#': 996,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 70,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '19,2',
#   'totalPremium': '1401,4',
#   'renewal': 'Y'},
#  {'insuree#': 997,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'No',
#   'insuredMonths': 13,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'Class A',
#   'healthRiders': '3,4',
#   'premiumFrequency': 1.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '102,25',
#   'totalPremium': '1359',
#   'renewal': 'N'},
#  {'insuree#': 998,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'Yes',
#   'hasKids': 'Yes',
#   'insuredMonths': 610,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'Yes',
#   'healthInsurance': 'No',
#   'healthRiders': nan,
#   'premiumFrequency': 12.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '24,1',
#   'totalPremium': '1551,6',
#   'renewal': 'Y'},
#  {'insuree#': 999,
#   'gender': 'M',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 11,
#   'termLifeInsurance': 'No',
#   'multipleTermLifePolicies': 'no term life policy taken',
#   'healthInsurance': 'Class B',
#   'healthRiders': '3',
#   'premiumFrequency': 3.0,
#   'eStatements': 'Yes',
#   'monthlyPremium': '416',
#   'totalPremium': '4706',
#   'renewal': 'N'},
#  {'insuree#': 1000,
#   'gender': 'F',
#   'is45OrOlder': 0.0,
#   'isMarried': 'No',
#   'hasKids': 'No',
#   'insuredMonths': 18,
#   'termLifeInsurance': 'Yes',
#   'multipleTermLifePolicies': 'No',
#   'healthInsurance': 'Class A',
#   'healthRiders': '2',
#   'premiumFrequency': 1.0,
#   'eStatements': 'No',
#   'monthlyPremium': '77,8',
#   'totalPremium': '1358,6',
#   'renewal': 'Y'},
#  ...]
